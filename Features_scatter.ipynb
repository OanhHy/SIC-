# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Student_performance_data _.csv")
data
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
data.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
if "StudentID" in data.columns:  
    data=data.drop("StudentID",axis=1)

# %%
data
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
features = ['Age', 'Gender', 'Ethnicity', 'ParentalEducation', 'StudyTimeWeekly', 'Absences', 'Tutoring', 
            'ParentalSupport', 'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA', 'GradeClass']
for i in features:
    plt.figure(figsize=(8, 5))
    sns.countplot(x=i, data= data)
    plt.show()

# %%
plt.figure(figsize=(6,8))
sns.scatterplot(x='GPA', y='GradeClass', data=data, hue='GradeClass', palette='cividis')
plt.title('Scatter Plot of GPA and GradeClass')
plt.xlabel('GPA')
plt.ylabel('GradeClass')
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.scatterplot(x='Absences', y='GradeClass', data=data, hue='GradeClass', palette='cividis')
plt.title('Scatter Plot of Absences and GradeClass')
plt.xlabel('Absences')
plt.ylabel('GradeClass')
plt.show()
